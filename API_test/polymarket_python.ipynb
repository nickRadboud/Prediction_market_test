# %% [markdown]
# # Polymarket API Python
#
# **Resources:**
# - [Polymarket API Docs](https://docs.polymarket.com/)
# - [Gamma API (Market Data)](https://gamma-api.polymarket.com/)
# - [Data API (User Data)](https://data-api.polymarket.com/)
# - [py-clob-client (3rd Party using Official SDK)](https://github.com/Polymarket/py-clob-client)

# %% [markdown]
# ## 1. Setup

# %%
# pip install py-clob-client requests

# %%
import requests
import time
import json
from pprint import pprint

from py_clob_client.client import ClobClient
from py_clob_client.clob_types import OrderArgs, MarketOrderArgs, OrderType, OpenOrderParams, BalanceAllowanceParams, AssetType
from py_clob_client.order_builder.constants import BUY, SELL

GAMMA_API = "https://gamma-api.polymarket.com"
DATA_API = "https://data-api.polymarket.com"
CLOB_API = "https://clob.polymarket.com"

# %% [markdown]
# ## 2. Market Discovery

# %%
# Fetch active markets sorted by volume
response = requests.get(
    f"{GAMMA_API}/markets",
    params={
        "limit": 1000,
        "active": True,
        "closed": False,
        "order": "volume24hr",
        "ascending": False
    }
)
markets = response.json()
print(f"Found {len(markets)} markets\n")
# Out:
# Found 500 markets

# %%
for m in markets[:5]:
    print(f"Question: {m['question']}")
    print(f"  Volume 24h: ${m.get('volume24hr', 0):,.0f}")
    print(f"  Liquidity: ${m.get('liquidityNum', 0):,.0f}")
    print(f"  Prices: {m.get('outcomePrices', 'N/A')}")
    print(f"end date: {m['endDate']}")
    print()
# Out:
# Question: Fed increases interest rates by 25+ bps after January 2026 meeting?
#   Volume 24h: $11,065,623
#   Liquidity: $7,110,259
#   Prices: ["0.0035", "0.9965"]
# end date: 2026-01-28T00:00:00Z
#
# Question: Fed decreases interest rates by 50+ bps after January 2026 meeting?
#   Volume 24h: $6,954,493
#   Liquidity: $2,401,094
#   Prices: ["0.0065", "0.9935"]
# end date: 2026-01-28T00:00:00Z
#
# Question: Will Meituan have the best AI model at the end of January 2026?
#   Volume 24h: $2,626,216
#   Liquidity: $75,351
#   Prices: ["0.0005", "0.9995"]
# end date: 2026-01-31T00:00:00Z
#
# Question: Fed decreases interest rates by 25 bps after January 2026 meeting?
#   Volume 24h: $1,748,558
#   Liquidity: $1,034,397
#   Prices: ["0.065", "0.935"]
# end date: 2026-01-28T00:00:00Z
#
# Question: Will Trump nominate Barron Trump as the next Fed chair?
#   Volume 24h: $1,720,517
#   Liquidity: $166,480
#   Prices: ["0.0005", "0.9995"]
# end date: 2026-12-31T00:00:00Z

# %% [markdown]
# ## 3. Market Deep Dive

# %%
market = markets[1]
market['outcomePrices']
# Out:
# '["0.0065", "0.9935"]'

# %%
print(f"Market: {market['question']}")
print(f"End Date: {market['endDate']}")
print(f"Condition ID: {market['conditionId']}")
# Out:
# Market: Fed decreases interest rates by 50+ bps after January 2026 meeting?
# End Date: 2026-01-28T00:00:00Z
# Condition ID: 0x17815081230e3b9c78b098162c33b1ffa68c4ec29c123d3d14989599e0c2e113

# %%
clob_token_ids = market.get('clobTokenIds')
clob_token_ids = json.loads(clob_token_ids)
print(f"Token IDs: {clob_token_ids}")

if len(clob_token_ids) >= 2:
    yes_token_id = clob_token_ids[0]
    no_token_id = clob_token_ids[1]
    print(f"YES token: {yes_token_id}")
    print(f"NO token: {no_token_id}")
# Out:
# Token IDs: ['11862165566757345985240476164489718219056735011698825377388402888080786399275', '71478852790279095447182996049071040792010759617668969799049179229104800573786']
# YES token: 11862165566757345985240476164489718219056735011698825377388402888080786399275
# NO token: 71478852790279095447182996049071040792010759617668969799049179229104800573786

# %% [markdown]
# ## 4. Order Book Analysis

# %%
# Read-only client for order book
client = ClobClient(CLOB_API)

# %%
# Fetch order book for YES token
if yes_token_id:
    book = client.get_order_book(yes_token_id)
    
    sorted_bids = sorted(book.bids, key=lambda x: float(x.price), reverse=True)
    sorted_asks = sorted(book.asks, key=lambda x: float(x.price), reverse=False)
    
    print("=== YES Token Order Book ===")
    print(f"\nTop 5 Asks (sell orders):")
    for ask in sorted_asks[:5]:
        print(f"  Price: {ask.price} | Size: {ask.size}")
        
    print(f"\nTop 5 Bids (buy orders):")
    for bid in sorted_bids[:5]:
        print(f"  Price: {bid.price} | Size: {bid.size}")
# Out:
# === YES Token Order Book ===
#
# Top 5 Asks (sell orders):
#   Price: 0.007 | Size: 2047339.48
#   Price: 0.008 | Size: 43658
#   Price: 0.009 | Size: 3377
#   Price: 0.01 | Size: 15090.78
#   Price: 0.011 | Size: 27809.37
#
# Top 5 Bids (buy orders):
#   Price: 0.006 | Size: 221949.03
#   Price: 0.005 | Size: 2748463.82
#   Price: 0.004 | Size: 1689498.98
#   Price: 0.003 | Size: 1523660.5
#   Price: 0.002 | Size: 2104144.81

# %%
# Get midpoint, prices, and spread
mid = client.get_midpoint(yes_token_id)
buy_price = client.get_price(yes_token_id, side="BUY")
sell_price = client.get_price(yes_token_id, side="SELL")
spread = client.get_spread(yes_token_id)

print(f"Midpoint: {mid['mid']}")
print(f"Best ask (buy at): {buy_price['price']}")
print(f"Best bid (sell at): {sell_price['price']}")
print(f"Spread: {spread['spread']}")
# Out:
# Midpoint: 0.0065
# Best ask (buy at): 0.006
# Best bid (sell at): 0.007
# Spread: 0.001

# %% [markdown]
# ## 5. Authentication

# %%
# Your credentials (keep these secret!)
FUNDER_ADDRESS = "your-wallet-address"  # For proxy wallets
PRIVATE_KEY = "your-private-key-here"  # Never commit this

# Signature types:
# 0 = EOA (MetaMask, hardware wallet)
# 1 = Email/Magic wallet
# 2 = Browser wallet proxy
SIGNATURE_TYPE = 1

# %%
# Initialize authenticated client
auth_client = ClobClient(
    CLOB_API,
    key=PRIVATE_KEY,
    chain_id=137,
    signature_type=SIGNATURE_TYPE,
    funder=FUNDER_ADDRESS
)

# Get & Set API credentials
creds = auth_client.derive_api_key()
auth_client.set_api_creds(creds)
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# Cell In[13], line 2
#       1 # Initialize authenticated client
# ----> 2 auth_client = ClobClient(
#       3     CLOB_API,
#       4     key=PRIVATE_KEY,
#       5     chain_id=137,
#       6     signature_type=SIGNATURE_TYPE,
#       7     funder=FUNDER_ADDRESS
#       8 )
#      10 # Get & Set API credentials
#      11 creds = auth_client.derive_api_key()
#
# File ~/Documents/market/.venv/lib/python3.12/site-packages/py_clob_client/client.py:140, in ClobClient.__init__(self, host, chain_id, key, creds, signature_type, funder, builder_config)
#     138 self.host = host[0:-1] if host.endswith("/") else host
#     139 self.chain_id = chain_id
# --> 140 self.signer = Signer(key, chain_id) if key else None
#     141 self.creds = creds
#     142 self.mode = self._get_client_mode()
#
# File ~/Documents/market/.venv/lib/python3.12/site-packages/py_clob_client/signer.py:9, in Signer.__init__(self, private_key, chain_id)
#       6 assert private_key is not None and chain_id is not None
#       8 self.private_key = private_key
# ----> 9 self.account = Account.from_key(private_key)
#      10 self.chain_id = chain_id
#
# File ~/Documents/market/.venv/lib/python3.12/site-packages/eth_utils/decorators.py:31, in combomethod.__get__.<locals>._wrapper(*args, **kwargs)
#      29     return self.method(obj, *args, **kwargs)
#      30 else:
# ---> 31     return self.method(objtype, *args, **kwargs)
#
# File ~/Documents/market/.venv/lib/python3.12/site-packages/eth_account/account.py:310, in Account.from_key(self, private_key)
#     287 @combomethod
#     288 def from_key(self, private_key: PrivateKeyType) -> LocalAccount:
#     289     r"""
#     290     Returns a convenient object for working with the given private key.
#     291
#    (...)    308         # but without the private key argument
#     309     """
# --> 310     key = self._parse_private_key(private_key)
#     311     return LocalAccount(key, self)
#
# File ~/Documents/market/.venv/lib/python3.12/site-packages/eth_utils/decorators.py:31, in combomethod.__get__.<locals>._wrapper(*args, **kwargs)
#      29     return self.method(obj, *args, **kwargs)
#      30 else:
# ---> 31     return self.method(objtype, *args, **kwargs)
#
# File ~/Documents/market/.venv/lib/python3.12/site-packages/eth_account/account.py:894, in Account._parse_private_key(self, key)
#     891 if isinstance(key, self._keys.PrivateKey):
#     892     return key
# --> 894 hb_key = HexBytes(key)
#     896 try:
#     897     return self._keys.PrivateKey(hb_key)
#
# File ~/Documents/market/.venv/lib/python3.12/site-packages/hexbytes/main.py:35, in HexBytes.__new__(cls, val)
#      34 def __new__(cls: Type[bytes], val: BytesLike) -> "HexBytes":
# ---> 35     bytesval = to_bytes(val)
#      36     return cast(HexBytes, super().__new__(cls, bytesval))
#
# File ~/Documents/market/.venv/lib/python3.12/site-packages/hexbytes/_utils.py:17, in to_bytes(val)
#      15     return val
#      16 elif isinstance(val, str):
# ---> 17     return hexstr_to_bytes(val)
#      18 elif isinstance(val, bytearray):
#      19     return bytes(val)
#
# File ~/Documents/market/.venv/lib/python3.12/site-packages/hexbytes/_utils.py:54, in hexstr_to_bytes(hexstr)
#      50     raise ValueError(
#      51         f"hex string {padded_hex} may only contain [0-9a-fA-F] characters"
#      52     )
#      53 else:
# ---> 54     return binascii.unhexlify(ascii_hex)
#
# Error: Non-hexadecimal digit found

# %%
balance = auth_client.get_balance_allowance(BalanceAllowanceParams(asset_type=AssetType.COLLATERAL))
usdc_balance = int(balance['balance']) / 1e6
print(f"USDC Balance: ${usdc_balance:.2f}")

# %% [markdown]
# ## 6. Place a Market Order

# %%
# Create a market order: Spend $5 on YES shares at market price
market_order = MarketOrderArgs(
    token_id=yes_token_id,
    amount=5.0,  # Dollar amount to spend
    side=BUY,
    order_type=OrderType.FOK  # Fill-or-Kill
)

signed_market_order = auth_client.create_market_order(market_order)
print("Market order signed!")

# %%
# Execute market order
response = auth_client.post_order(signed_market_order, OrderType.FOK)
print("Market order executed!")
pprint(response)

# %% [markdown]
# ## 7. Place a Limit Order

# %%
# Create a limit order: Buy 10 YES shares at $0.50
limit_order = OrderArgs(
    token_id=yes_token_id,
    price=0.001,  # Price per share
    size=10.0,   # Number of shares
    side=BUY
)

# Sign the order
signed_order = auth_client.create_order(limit_order)
print("Order signed!")

# %%
# Post the order (GTC = Good Till Cancelled)
response = auth_client.post_order(signed_order, OrderType.GTC)
print(f"Order placed!")
pprint(response)

# %% [markdown]
# ## 8. Open Orders

# %%
# Get your open orders
open_orders = auth_client.get_orders(OpenOrderParams())
print(f"Open orders: {len(open_orders)}")

for order in open_orders[:5]:
    print(f"  ID: {order['id'][:20]}...")
    print(f"  Side: {order['side']} | Price: {order['price']} | Size: {order['original_size']}")
    print()

# %% [markdown]
# ## 9. Cancel Orders

# %%
# Cancel a specific order
open_orders = auth_client.get_orders(OpenOrderParams())
if open_orders:
    order_id = open_orders[0]["id"]
    result = auth_client.cancel(order_id)
    print(f"Cancelled order: {order_id[:20]}...")
    pprint(result)

# %%
# Cancel all orders
result = auth_client.cancel_all()
print("All orders cancelled!")
pprint(result)

# %% [markdown]
# ## 10. BONUS 1: Price Tracker

# %%
def track_price(token_id, duration_seconds=30, interval=5):
    """Track price changes in real-time."""
    print(f"Tracking price for {duration_seconds}s...\n")

    client = ClobClient(CLOB_API)
    start_time = time.time()
    prices = []

    while time.time() - start_time < duration_seconds:
        mid = client.get_midpoint(token_id)
        mid_price = float(mid['mid'])
        timestamp = time.strftime("%H:%M:%S")
        prices.append(mid_price)

        change = ""
        if len(prices) > 1:
            diff = prices[-1] - prices[-2]
            change = f" ({'+' if diff >= 0 else ''}{diff:.4f})"

        print(f"[{timestamp}] Price: {mid_price}{change}")
        time.sleep(interval)

    print(f"\nTotal change: {prices[-1] - prices[0]:.4f}")
    return prices

# %%
# Run the tracker
prices = track_price(yes_token_id, duration_seconds=10, interval=1)
# Out:
# Tracking price for 10s...
#
# [19:34:53] Price: 0.0065
# [19:34:54] Price: 0.0065 (+0.0000)
# [19:34:55] Price: 0.0065 (+0.0000)
# [19:34:56] Price: 0.0065 (+0.0000)
# [19:34:57] Price: 0.0065 (+0.0000)
# [19:34:58] Price: 0.0065 (+0.0000)
# [19:34:59] Price: 0.0065 (+0.0000)
# [19:35:00] Price: 0.0065 (+0.0000)
# [19:35:01] Price: 0.0065 (+0.0000)
# [19:35:02] Price: 0.0065 (+0.0000)
#
# Total change: 0.0000

# %% [markdown]
# ## 11. BONUS 2: Address Position Tracker

# %%
def get_user_positions(wallet_address):
    """Get a user's current positions."""
    url = f"{DATA_API}/positions"
    params = {"user": wallet_address}
    response = requests.get(url, params=params)
    return response.json()

# %%
address = "0x6a72f61820b26b1fe4d956e17b6dc2a1ea3033ee"
positions = get_user_positions(address)
positions
# Out:
# [{'proxyWallet': '0x6a72f61820b26b1fe4d956e17b6dc2a1ea3033ee',
#   'asset': '105953956915150002522974165882693825582092111865946642103065245868242929489995',
#   'conditionId': '0x2a496f947e51993cdb4af43c8dd851780a8bac86c06cd7ad5dcd5741f46ce843',
#   'size': 1213870.438533,
#   'avgPrice': 0.028785,
#   'initialValue': 34941.2605731724,
#   'currentValue': 0,
#   'cashPnl': -34941.26057317241,
#   'percentPnl': -100,
#   'totalBought': 1213870.438533,
#   'realizedPnl': 0,
#   'percentRealizedPnl': -99.99999999999997,
#   'curPrice': 0,
#   'redeemable': True,
#   'mergeable': False,
#   'title': 'Will Jake Paul vs. Anthony Joshua have no official winner?',
#   'slug': 'will-the-fight-end-in-another-outcome',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/boxing-jake-paul-vs-anthony-joshua-third-option-included-O9JsNln3VFfX.jpg',
#   'eventId': '85540',
#   'eventSlug': 'boxing-jake-paul-vs-anthony-joshua-third-option-included',
#   'outcome': 'Yes',
#   'outcomeIndex': 0,
#   'oppositeOutcome': 'No',
#   'oppositeAsset': '45564989537666625345712673679525402717096208123026156293976313884501160337709',
#   'endDate': '2025-12-19',
#   'negativeRisk': True},
#  {'proxyWallet': '0x6a72f61820b26b1fe4d956e17b6dc2a1ea3033ee',
#   'asset': '82345450310464453987407282444723168705360389692065005651960520789938025753903',
#   'conditionId': '0xa95cbda893d52cde50ac9cbb53833bbfdffc03c91be41ccd810765cb4cd34b77',
#   'size': 1209999.971102,
#   'avgPrice': 0.55,
#   'initialValue': 665499.9841060999,
#   'currentValue': 0,
#   'cashPnl': -665499.9841061,
#   'percentPnl': -100,
#   'totalBought': 1209999.971102,
#   'realizedPnl': 0,
#   'percentRealizedPnl': -99.99999999999997,
#   'curPrice': 0,
#   'redeemable': True,
#   'mergeable': False,
#   'title': 'Blue Jays vs. Mariners',
#   'slug': 'mlb-tor-sea-2025-10-15',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/Repetitive-markets/MLB.jpg',
#   'eventId': '59509',
#   'eventSlug': 'mlb-tor-sea-2025-10-15',
#   'outcome': 'Mariners',
#   'outcomeIndex': 1,
#   'oppositeOutcome': 'Blue Jays',
#   'oppositeAsset': '114391734370695142280394652097950033388554188400283825660815141850425388968842',
#   'endDate': '2025-10-23',
#   'negativeRisk': False},
#  {'proxyWallet': '0x6a72f61820b26b1fe4d956e17b6dc2a1ea3033ee',
#   'asset': '15722178229126073851259928986980208404743149470678370242610886528254771774908',
#   'conditionId': '0x8e52f21c7fca56bb681ee259e68433c22430ae066fe5e2c5284fff591eb4387f',
#   'size': 878557.66,
#   'avgPrice': 0.52,
#   'initialValue': 456849.9832,
#   'currentValue': 0,
#   'cashPnl': -456849.9832,
#   'percentPnl': -100,
#   'totalBought': 878557.66,
#   'realizedPnl': 0,
#   'percentRealizedPnl': -100,
#   'curPrice': 0,
#   'redeemable': True,
#   'mergeable': False,
#   'title': 'Spread: Lions (-3.5)',
#   'slug': 'nfl-dal-det-2025-12-04-spread-home-3pt5',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nfl.png',
#   'eventId': '89365',
#   'eventSlug': 'nfl-dal-det-2025-12-04',
#   'outcome': 'Cowboys',
#   'outcomeIndex': 1,
#   'oppositeOutcome': 'Lions',
#   'oppositeAsset': '66762004966397611229182756120748854338843747454842586789364529758459067623076',
#   'endDate': '2025-12-05',
#   'negativeRisk': False},
#  {'proxyWallet': '0x6a72f61820b26b1fe4d956e17b6dc2a1ea3033ee',
#   'asset': '72685162394098505217895638060393901041260225434938300730127268362092284806692',
#   'conditionId': '0xc40cbb2d7f5d2c43c624bd5b1d0b18cd3d0682b3937363ec7c1ad1d13bee107e',
#   'size': 860000.1215,
#   'avgPrice': 0.072213,
#   'initialValue': 62103.188773879505,
#   'currentValue': 0,
#   'cashPnl': -62103.188773879505,
#   'percentPnl': -100,
#   'totalBought': 860000.1215,
#   'realizedPnl': 0,
#   'percentRealizedPnl': -100,
#   'curPrice': 0,
#   'redeemable': True,
#   'mergeable': False,
#   'title': 'Will Andrew Cuomo win the 2025 NYC mayoral election?',
#   'slug': 'will-andrew-cuomo-win-the-2025-nyc-mayoral-election',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/will-andrew-cuomo-win-the-2025-nyc-mayoral-election-CFbNR1wG_T2X.jpg',
#   'eventId': '23246',
#   'eventSlug': 'new-york-city-mayoral-election',
#   'outcome': 'Yes',
#   'outcomeIndex': 0,
#   'oppositeOutcome': 'No',
#   'oppositeAsset': '104468181147316868388088006861839293041095272602974154655578369735976654024471',
#   'endDate': '2025-11-04',
#   'negativeRisk': True},
#  {'proxyWallet': '0x6a72f61820b26b1fe4d956e17b6dc2a1ea3033ee',
#   'asset': '5011372677829660712953281699910973269647418696475382315842932138492440463792',
#   'conditionId': '0x6afffb701b4227dbd4c399523a0ea7b9169614ad168ba852dd832afc8caeee86',
#   'size': 848035.884586,
#   'avgPrice': 0.504657,
#   'initialValue': 427967.245407517,
#   'currentValue': 0,
#   'cashPnl': -427967.245407517,
#   'percentPnl': -100,
#   'totalBought': 870265.687086,
#   'realizedPnl': -222.209105,
#   'percentRealizedPnl': -100.0000000505957,
#   'curPrice': 0,
#   'redeemable': True,
#   'mergeable': True,
#   'title': 'Ravens vs. Packers',
#   'slug': 'nfl-bal-gb-2025-12-27',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nfl.png',
#   'eventId': '104780',
#   'eventSlug': 'nfl-bal-gb-2025-12-27',
#   'outcome': 'Packers',
#   'outcomeIndex': 1,
#   'oppositeOutcome': 'Ravens',
#   'oppositeAsset': '94151132652556398897966832966820303807252393112229047465223828277052199339425',
#   'endDate': '2025-12-28',
#   'negativeRisk': False},
#  {'proxyWallet': '0x6a72f61820b26b1fe4d956e17b6dc2a1ea3033ee',
#   'asset': '29861167073487287911290708283587899010738846835462845059174896974888935671400',
#   'conditionId': '0x838162b7ed9eec6f8d6fa9bcd8dbbbf346a1e24d539d3ef724783e4ede4940bc',
#   'size': 810000.02894,
#   'avgPrice': 0.641242,
#   'initialValue': 519406.0385575435,
#   'currentValue': 0,
#   'cashPnl': -519406.0385575435,
#   'percentPnl': -100,
#   'totalBought': 810000.02894,
#   'realizedPnl': 0,
#   'percentRealizedPnl': -100.00000000000003,
#   'curPrice': 0,
#   'redeemable': True,
#   'mergeable': False,
#   'title': 'Blue Jays vs. Dodgers',
#   'slug': 'mlb-tor-lad-2025-10-29',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/Repetitive-markets/MLB.jpg',
#   'eventId': '66268',
#   'eventSlug': 'mlb-tor-lad-2025-10-29',
#   'outcome': 'Dodgers',
#   'outcomeIndex': 1,
#   'oppositeOutcome': 'Blue Jays',
#   'oppositeAsset': '72378088845888831036964789022900697468284849475218730285015948493579606924868',
#   'endDate': '2025-11-06',
#   'negativeRisk': False},
#  {'proxyWallet': '0x6a72f61820b26b1fe4d956e17b6dc2a1ea3033ee',
#   'asset': '14215175022187003453415954495706037647589075082501436753196249065748822209265',
#   'conditionId': '0x83b32407eb2c89ac34e400dc41dc80dd26d60d3fea823054a972738d16d10ed8',
#   'size': 804282.166886,
#   'avgPrice': 0.633396,
#   'initialValue': 509429.1073769249,
#   'currentValue': 0,
#   'cashPnl': -509429.10737692483,
#   'percentPnl': -100,
#   'totalBought': 1039414.182216,
#   'realizedPnl': -31365.670316,
#   'percentRealizedPnl': -100.00000476420693,
#   'curPrice': 0,
#   'redeemable': True,
#   'mergeable': False,
#   'title': 'Chiefs vs. Cowboys',
#   'slug': 'nfl-kc-dal-2025-11-27',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nfl.png',
#   'eventId': '89350',
#   'eventSlug': 'nfl-kc-dal-2025-11-27',
#   'outcome': 'Chiefs',
#   'outcomeIndex': 0,
#   'oppositeOutcome': 'Cowboys',
#   'oppositeAsset': '49380715182446926317246860961188578370185264154666110778660777174117258896871',
#   'endDate': '2025-11-27',
#   'negativeRisk': False},
#  {'proxyWallet': '0x6a72f61820b26b1fe4d956e17b6dc2a1ea3033ee',
#   'asset': '40822607585190461195073710936487425414197193102743166888221781257244481598994',
#   'conditionId': '0x94b10c0bfeda43011714c678f959b6c2429adf6bef06d4e1f7703a2b137d6ff0',
#   'size': 792342.191913,
#   'avgPrice': 0.520356,
#   'initialValue': 412300.013615081,
#   'currentValue': 0,
#   'cashPnl': -412300.013615081,
#   'percentPnl': -100,
#   'totalBought': 792342.191913,
#   'realizedPnl': 0,
#   'percentRealizedPnl': -99.99999999999999,
#   'curPrice': 0,
#   'redeemable': True,
#   'mergeable': False,
#   'title': 'Alabama vs. Oklahoma',
#   'slug': 'cfb-ala-okl-2025-12-19',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/espn+college+football+logo.png',
#   'eventId': '105898',
#   'eventSlug': 'cfb-ala-okl-2025-12-19',
#   'outcome': 'Oklahoma',
#   'outcomeIndex': 1,
#   'oppositeOutcome': 'Alabama',
#   'oppositeAsset': '70397070945080281371503368041633716131190827582594191712463794311321843229891',
#   'endDate': '2025-12-20',
#   'negativeRisk': False},
#  {'proxyWallet': '0x6a72f61820b26b1fe4d956e17b6dc2a1ea3033ee',
#   'asset': '46057387741351405101467618572506222587481846397503150276396678936624442925907',
#   'conditionId': '0xa3a4c9ed251610a458c1c65a207688705e4d54f92a2568477cb978e92fa3243f',
#   'size': 749999.982038,
#   'avgPrice': 0.494669,
#   'initialValue': 371001.7411147554,
#   'currentValue': 0,
#   'cashPnl': -371001.74111475545,
#   'percentPnl': -100,
#   'totalBought': 749999.982038,
#   'realizedPnl': 0,
#   'percentRealizedPnl': -99.99999999999999,
#   'curPrice': 0,
#   'redeemable': True,
#   'mergeable': False,
#   'title': 'New Mexico vs. Minnesota',
#   'slug': 'cfb-nmx-minnst-2025-12-26',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/espn+college+football+logo.png',
#   'eventId': '118100',
#   'eventSlug': 'cfb-nmx-minnst-2025-12-26',
#   'outcome': 'New Mexico',
#   'outcomeIndex': 0,
#   'oppositeOutcome': 'Minnesota',
#   'oppositeAsset': '104901026808192107070170133402692339971190599106120504812542132705149243549563',
#   'endDate': '2025-12-26',
#   'negativeRisk': False},
#  {'proxyWallet': '0x6a72f61820b26b1fe4d956e17b6dc2a1ea3033ee',
#   'asset': '3283464780416605157026912923382835718831458678323334087773830626945516630468',
#   'conditionId': '0x04564b7d917c809846ca046e3864fa0de47d4246f4793bad88d9371b6066b350',
#   'size': 690805.436414,
#   'avgPrice': 0.475789,
#   'initialValue': 328677.62778598064,
#   'currentValue': 0,
#   'cashPnl': -328677.62778598064,
#   'percentPnl': -100,
#   'totalBought': 690805.436414,
#   'realizedPnl': 0,
#   'percentRealizedPnl': -100,
#   'curPrice': 0,
#   'redeemable': True,
#   'mergeable': False,
#   'title': 'Spread: Timberwolves (-8.5)',
#   'slug': 'nba-lac-min-2025-12-06-spread-home-8pt5',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/super+cool+basketball+in+red+and+blue+wow.png',
#   'eventId': '94026',
#   'eventSlug': 'nba-lac-min-2025-12-06',
#   'outcome': 'Timberwolves',
#   'outcomeIndex': 0,
#   'oppositeOutcome': 'Clippers',
#   'oppositeAsset': '37471360709623239591564197826928859899108919788067263263435148978382043556998',
#   'endDate': '2025-12-07',
#   'negativeRisk': False},
#  {'proxyWallet': '0x6a72f61820b26b1fe4d956e17b6dc2a1ea3033ee',
#   'asset': '66505593931173762559739994147404722634137806147436559163462372095501200724431',
#   'conditionId': '0x6a84be0c820e4eafcfd2227894c239cb600a4e8a0073e77cf67903ae015cc71e',
#   'size': 638932.153251,
#   'avgPrice': 0.518341,
#   'initialValue': 331184.7312482766,
#   'currentValue': 0,
#   'cashPnl': -331184.7312482766,
#   'percentPnl': -100,
#   'totalBought': 718290.424451,
#   'realizedPnl': -1455.510052,
#   'percentRealizedPnl': -100.00000039093051,
#   'curPrice': 0,
#   'redeemable': True,
#   'mergeable': True,
#   'title': 'Texans vs. Chargers',
#   'slug': 'nfl-hou-lac-2025-12-27',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nfl.png',
#   'eventId': '104781',
#   'eventSlug': 'nfl-hou-lac-2025-12-27',
#   'outcome': 'Chargers',
#   'outcomeIndex': 1,
#   'oppositeOutcome': 'Texans',
#   'oppositeAsset': '19165851215407134086264878404868477335229661577693324749321152643356423889292',
#   'endDate': '2025-12-27',
#   'negativeRisk': False},
#  {'proxyWallet': '0x6a72f61820b26b1fe4d956e17b6dc2a1ea3033ee',
#   'asset': '34056278809925221126265244267396141443651354143503535632271178716094155961410',
#   'conditionId': '0xac29009023db8f4bea0ac9ab78b3fa8839e544851f2162b55db0ec6155311c52',
#   'size': 600000,
#   'avgPrice': 0.514999,
#   'initialValue': 308999.4,
#   'currentValue': 0,
#   'cashPnl': -308999.4,
#   'percentPnl': -100,
#   'totalBought': 600000,
#   'realizedPnl': 0,
#   'percentRealizedPnl': -100,
#   'curPrice': 0,
#   'redeemable': True,
#   'mergeable': False,
#   'title': 'Spread: Steelers (-3.5)',
#   'slug': 'nfl-mia-pit-2025-12-15-spread-home-3pt5',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nfl.png',
#   'eventId': '95702',
#   'eventSlug': 'nfl-mia-pit-2025-12-15',
#   'outcome': 'Dolphins',
#   'outcomeIndex': 1,
#   'oppositeOutcome': 'Steelers',
#   'oppositeAsset': '80695125558556765468924399407685141981943562262915012336553030749857921891095',
#   'endDate': '2025-12-15',
#   'negativeRisk': False},
#  {'proxyWallet': '0x6a72f61820b26b1fe4d956e17b6dc2a1ea3033ee',
#   'asset': '57835322776454817418804598909754440401163191273583124412176681013159547471489',
#   'conditionId': '0x9332d0e9b24d5e20d1dfcda03fec3ed34c5625824406afacf444d33958736bda',
#   'size': 599999.944492,
#   'avgPrice': 0.49,
#   'initialValue': 293999.97280108,
#   'currentValue': 0,
#   'cashPnl': -293999.97280108003,
#   'percentPnl': -100,
#   'totalBought': 599999.944492,
#   'realizedPnl': 0,
#   'percentRealizedPnl': -100,
#   'curPrice': 0,
#   'redeemable': True,
#   'mergeable': False,
#   'title': 'Spread: Raptors (-6.5)',
#   'slug': 'nba-cha-tor-2025-12-05-spread-home-6pt5',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/super+cool+basketball+in+red+and+blue+wow.png',
#   'eventId': '93320',
#   'eventSlug': 'nba-cha-tor-2025-12-05',
#   'outcome': 'Raptors',
#   'outcomeIndex': 0,
#   'oppositeOutcome': 'Hornets',
#   'oppositeAsset': '6717340096247853784689194592736606565657687047337758903064614089287586644461',
#   'endDate': '2025-12-06',
#   'negativeRisk': False},
#  {'proxyWallet': '0x6a72f61820b26b1fe4d956e17b6dc2a1ea3033ee',
#   'asset': '52240534597876551731169435563386055088454147723882459956480017363260963625822',
#   'conditionId': '0xa3e1a124a8fcb85e220a60e52049d1ebd2afb87fc8034ceaeb6567c8b968239e',
#   'size': 544395.394959,
#   'avgPrice': 0.432938,
#   'initialValue': 235689.45350275954,
#   'currentValue': 0,
#   'cashPnl': -235689.4535027595,
#   'percentPnl': -100,
#   'totalBought': 552281.3249,
#   'realizedPnl': 432.243591,
#   'percentRealizedPnl': -99.99999981922329,
#   'curPrice': 0,
#   'redeemable': True,
#   'mergeable': False,
#   'title': 'Bills vs. Patriots',
#   'slug': 'nfl-buf-ne-2025-12-14',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nfl.png',
#   'eventId': '93957',
#   'eventSlug': 'nfl-buf-ne-2025-12-14',
#   'outcome': 'Patriots',
#   'outcomeIndex': 1,
#   'oppositeOutcome': 'Bills',
#   'oppositeAsset': '63318541023611879372668088232945116356843392132099065902537104234302958593551',
#   'endDate': '2025-12-14',
#   'negativeRisk': False},
#  {'proxyWallet': '0x6a72f61820b26b1fe4d956e17b6dc2a1ea3033ee',
#   'asset': '85442461071243883173373412170675697421736999439507657641598429651582131586635',
#   'conditionId': '0x00ae779e9d90097c2a4b1fea610772b5cad5ed743accc476499ea292fec710b3',
#   'size': 528929.711955,
#   'avgPrice': 0.547562,
#   'initialValue': 289621.8109375037,
#   'currentValue': 0,
#   'cashPnl': -289621.8109375037,
#   'percentPnl': -100,
#   'totalBought': 528929.711955,
#   'realizedPnl': 0,
#   'percentRealizedPnl': -99.99999999999997,
#   'curPrice': 0,
#   'redeemable': True,
#   'mergeable': False,
#   'title': 'Bulls vs. Pacers',
#   'slug': 'nba-chi-ind-2025-11-29',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/super+cool+basketball+in+red+and+blue+wow.png',
#   'eventId': '88373',
#   'eventSlug': 'nba-chi-ind-2025-11-29',
#   'outcome': 'Bulls',
#   'outcomeIndex': 0,
#   'oppositeOutcome': 'Pacers',
#   'oppositeAsset': '51065159123993832409190825353688237740102015902625912355448441465572556380694',
#   'endDate': '2025-11-30',
#   'negativeRisk': False},
#  {'proxyWallet': '0x6a72f61820b26b1fe4d956e17b6dc2a1ea3033ee',
#   'asset': '68786128710811325549820972869194142716865180296775695577952910315061460142209',
#   'conditionId': '0x355b65886662e6e21752737c5bc877827bdf05cbdfe3fdb5bbaa9201798ecaf5',
#   'size': 506920.923251,
#   'avgPrice': 0.379863,
#   'initialValue': 192560.50266889462,
#   'currentValue': 0,
#   'cashPnl': -192560.50266889462,
#   'percentPnl': -100,
#   'totalBought': 506920.923251,
#   'realizedPnl': 0,
#   'percentRealizedPnl': -100,
#   'curPrice': 0,
#   'redeemable': True,
#   'mergeable': False,
#   'title': 'Pelicans vs. Nets',
#   'slug': 'nba-nop-bkn-2025-12-06',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/super+cool+basketball+in+red+and+blue+wow.png',
#   'eventId': '94012',
#   'eventSlug': 'nba-nop-bkn-2025-12-06',
#   'outcome': 'Pelicans',
#   'outcomeIndex': 0,
#   'oppositeOutcome': 'Nets',
#   'oppositeAsset': '98978524542165102433089718590585875121131084164490552175369446470985764620248',
#   'endDate': '2025-12-06',
#   'negativeRisk': False},
#  {'proxyWallet': '0x6a72f61820b26b1fe4d956e17b6dc2a1ea3033ee',
#   'asset': '13094498429043262538336168554322406952756859431736544943974983877714521454902',
#   'conditionId': '0x39e493c3cd953e45a632f4f5dde639ccd37f97743203be9c1eb01fbb155a4803',
#   'size': 504659.350942,
#   'avgPrice': 0.479907,
#   'initialValue': 242189.5551325224,
#   'currentValue': 0,
#   'cashPnl': -242189.55513252236,
#   'percentPnl': -100,
#   'totalBought': 504659.350942,
#   'realizedPnl': 0,
#   'percentRealizedPnl': -100.00000000000003,
#   'curPrice': 0,
#   'redeemable': True,
#   'mergeable': False,
#   'title': 'Spread: Grizzlies (-12.5)',
#   'slug': 'nba-was-mem-2025-12-20-spread-home-12pt5',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/super+cool+basketball+in+red+and+blue+wow.png',
#   'eventId': '104888',
#   'eventSlug': 'nba-was-mem-2025-12-20',
#   'outcome': 'Grizzlies',
#   'outcomeIndex': 0,
#   'oppositeOutcome': 'Wizards',
#   'oppositeAsset': '4765501864982032589494809396214706270671021091620334552669038388080328898101',
#   'endDate': '2025-12-21',
#   'negativeRisk': False},
#  {'proxyWallet': '0x6a72f61820b26b1fe4d956e17b6dc2a1ea3033ee',
#   'asset': '86732688737288642155632497522768484007739739893791693459513792601743710743519',
#   'conditionId': '0xe35df1a2cf9262b6a4b8aa4a49a21ba22a0d1e5a277d94bb856a250479cca065',
#   'size': 500000,
#   'avgPrice': 0.47,
#   'initialValue': 235000,
#   'currentValue': 0,
#   'cashPnl': -235000,
#   'percentPnl': -100,
#   'totalBought': 500000,
#   'realizedPnl': 0,
#   'percentRealizedPnl': -100,
#   'curPrice': 0,
#   'redeemable': True,
#   'mergeable': False,
#   'title': 'Spread: Pistons (-9.5)',
#   'slug': 'nba-atl-det-2025-12-01-spread-home-9pt5',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/super+cool+basketball+in+red+and+blue+wow.png',
#   'eventId': '90106',
#   'eventSlug': 'nba-atl-det-2025-12-01',
#   'outcome': 'Pistons',
#   'outcomeIndex': 0,
#   'oppositeOutcome': 'Hawks',
#   'oppositeAsset': '15318547140179587036440780658700259879079666326048649203557410383829719825527',
#   'endDate': '2025-12-02',
#   'negativeRisk': False},
#  {'proxyWallet': '0x6a72f61820b26b1fe4d956e17b6dc2a1ea3033ee',
#   'asset': '48625135761353189791891159988349917838906414986556820672533922345724301391017',
#   'conditionId': '0x17375bb67194287cd710641e537c649ad08a2540e0c67f8ad945cdb03869a2ea',
#   'size': 500000,
#   'avgPrice': 0.49,
#   'initialValue': 245000,
#   'currentValue': 0,
#   'cashPnl': -245000,
#   'percentPnl': -100,
#   'totalBought': 500000,
#   'realizedPnl': 0,
#   'percentRealizedPnl': -100,
#   'curPrice': 0,
#   'redeemable': True,
#   'mergeable': False,
#   'title': 'Spread: Warriors (-6.5)',
#   'slug': 'nba-mil-gsw-2026-01-07-spread-home-6pt5',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/super+cool+basketball+in+red+and+blue+wow.png',
#   'eventId': '136921',
#   'eventSlug': 'nba-mil-gsw-2026-01-07',
#   'outcome': 'Bucks',
#   'outcomeIndex': 1,
#   'oppositeOutcome': 'Warriors',
#   'oppositeAsset': '22137698132739055643011229799311203419897870274051184891162412855180875855119',
#   'endDate': '2026-01-08',
#   'negativeRisk': False},
#  {'proxyWallet': '0x6a72f61820b26b1fe4d956e17b6dc2a1ea3033ee',
#   'asset': '73582218226716770401234077986084042436666229240345112455736858508262602815933',
#   'conditionId': '0x795106b05c543e7aaf06c998e07cc42a07287a6b234ee793cfe43b28200163c2',
#   'size': 494816.316981,
#   'avgPrice': 0.530845,
#   'initialValue': 262670.7677877789,
#   'currentValue': 0,
#   'cashPnl': -262670.767787779,
#   'percentPnl': -100,
#   'totalBought': 565270.778699,
#   'realizedPnl': -2173.167871,
#   'percentRealizedPnl': -100.00000072421749,
#   'curPrice': 0,
#   'redeemable': True,
#   'mergeable': False,
#   'title': 'Chargers vs. Cowboys',
#   'slug': 'nfl-lac-dal-2025-12-21',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nfl.png',
#   'eventId': '99230',
#   'eventSlug': 'nfl-lac-dal-2025-12-21',
#   'outcome': 'Cowboys',
#   'outcomeIndex': 1,
#   'oppositeOutcome': 'Chargers',
#   'oppositeAsset': '3544747547225867259138178781913934171255697196708144729174720787129127288449',
#   'endDate': '2025-12-21',
#   'negativeRisk': False},
#  {'proxyWallet': '0x6a72f61820b26b1fe4d956e17b6dc2a1ea3033ee',
#   'asset': '53725554758829467872220332927859141619620067547123097464038175368776895176217',
#   'conditionId': '0xadbe599af220e164823a2d6de7ca4dc1f82c801529ef659da3356e05d91f13a9',
#   'size': 475000,
#   'avgPrice': 0.48,
#   'initialValue': 228000,
#   'currentValue': 0,
#   'cashPnl': -228000,
#   'percentPnl': -100,
#   'totalBought': 475000,
#   'realizedPnl': 0,
#   'percentRealizedPnl': -100,
#   'curPrice': 0,
#   'redeemable': True,
#   'mergeable': False,
#   'title': 'Spread: 49ers (-3.5)',
#   'slug': 'nfl-chi-sf-2025-12-28-spread-home-3pt5',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nfl.png',
#   'eventId': '105640',
#   'eventSlug': 'nfl-chi-sf-2025-12-28',
#   'outcome': 'Bears',
#   'outcomeIndex': 1,
#   'oppositeOutcome': '49ers',
#   'oppositeAsset': '20395391629122114194968580624013794776662414107889137272940317241830359084591',
#   'endDate': '2025-12-29',
#   'negativeRisk': False},
#  {'proxyWallet': '0x6a72f61820b26b1fe4d956e17b6dc2a1ea3033ee',
#   'asset': '44981476928533336005207364947806469395451087952631540682599018527321063504838',
#   'conditionId': '0x9de10ba1a707de8b5f5ed1fc8a56059e1e73822454b62643cdb394b36b20f171',
#   'size': 474104.498384,
#   'avgPrice': 0.469994,
#   'initialValue': 222826.26961348968,
#   'currentValue': 0,
#   'cashPnl': -222826.2696134897,
#   'percentPnl': -100,
#   'totalBought': 474104.498384,
#   'realizedPnl': 0,
#   'percentRealizedPnl': -99.99999999999999,
#   'curPrice': 0,
#   'redeemable': True,
#   'mergeable': False,
#   'title': 'Rockets vs. Nuggets',
#   'slug': 'nba-hou-den-2025-12-20',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/super+cool+basketball+in+red+and+blue+wow.png',
#   'eventId': '104831',
#   'eventSlug': 'nba-hou-den-2025-12-20',
#   'outcome': 'Nuggets',
#   'outcomeIndex': 1,
#   'oppositeOutcome': 'Rockets',
#   'oppositeAsset': '54829853978330669429551251905778214074128014124609781186771015417529556703558',
#   'endDate': '2025-12-20',
#   'negativeRisk': False},
#  {'proxyWallet': '0x6a72f61820b26b1fe4d956e17b6dc2a1ea3033ee',
#   'asset': '53102025186773252390423873247047300925037285765906458894745236532311807992700',
#   'conditionId': '0xc7a1ca12713d914386fe7da7fe705f375f9d9761910c727c22d5050af54939f8',
#   'size': 450000,
#   'avgPrice': 0.48,
#   'initialValue': 216000,
#   'currentValue': 0,
#   'cashPnl': -216000,
#   'percentPnl': -100,
#   'totalBought': 450000,
#   'realizedPnl': 0,
#   'percentRealizedPnl': -100,
#   'curPrice': 0,
#   'redeemable': True,
#   'mergeable': False,
#   'title': 'Spread: Cowboys (-5.5)',
#   'slug': 'nfl-min-dal-2025-12-14-spread-home-5pt5',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nfl.png',
#   'eventId': '94784',
#   'eventSlug': 'nfl-min-dal-2025-12-14',
#   'outcome': 'Cowboys',
#   'outcomeIndex': 0,
#   'oppositeOutcome': 'Vikings',
#   'oppositeAsset': '46180186273319615925474217441860148692177951022604481256055883298639949296139',
#   'endDate': '2025-12-15',
#   'negativeRisk': False},
#  {'proxyWallet': '0x6a72f61820b26b1fe4d956e17b6dc2a1ea3033ee',
#   'asset': '59401461657303196254741455576303328648285034688952707448371045730270120668366',
#   'conditionId': '0xfed00dec279879ea01aac99c0f0261d9f48ca49219cce842f7b85342fdd2825d',
#   'size': 442988.87219,
#   'avgPrice': 0.599929,
#   'initialValue': 265761.87110407447,
#   'currentValue': 0,
#   'cashPnl': -265761.8711040745,
#   'percentPnl': -100,
#   'totalBought': 442988.87219,
#   'realizedPnl': 0,
#   'percentRealizedPnl': -99.99999999999999,
#   'curPrice': 0,
#   'redeemable': True,
#   'mergeable': False,
#   'title': 'Nuggets vs. Magic',
#   'slug': 'nba-den-orl-2025-12-27',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/super+cool+basketball+in+red+and+blue+wow.png',
#   'eventId': '115452',
#   'eventSlug': 'nba-den-orl-2025-12-27',
#   'outcome': 'Nuggets',
#   'outcomeIndex': 0,
#   'oppositeOutcome': 'Magic',
#   'oppositeAsset': '69264680031686428435161625889000883532833257014248271240336711372206146271706',
#   'endDate': '2025-12-28',
#   'negativeRisk': False},
#  {'proxyWallet': '0x6a72f61820b26b1fe4d956e17b6dc2a1ea3033ee',
#   'asset': '89949029784213975613034513385950500609779434397660436757320864226369266418900',
#   'conditionId': '0x8b79fed4a05d97f282140be294cd4f86faf9580cb122642a4d87399f7dbc694a',
#   'size': 429521.454076,
#   'avgPrice': 0.56,
#   'initialValue': 240532.01428256,
#   'currentValue': 0,
#   'cashPnl': -240532.01428256003,
#   'percentPnl': -100,
#   'totalBought': 429521.454076,
#   'realizedPnl': 0,
#   'percentRealizedPnl': -99.99999999999999,
#   'curPrice': 0,
#   'redeemable': True,
#   'mergeable': False,
#   'title': 'Mavericks vs. Kings',
#   'slug': 'nba-dal-sac-2025-12-27',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/super+cool+basketball+in+red+and+blue+wow.png',
#   'eventId': '115445',
#   'eventSlug': 'nba-dal-sac-2025-12-27',
#   'outcome': 'Mavericks',
#   'outcomeIndex': 0,
#   'oppositeOutcome': 'Kings',
#   'oppositeAsset': '21850655499897395541660019641336094366798284892968583033593600666044580014592',
#   'endDate': '2025-12-27',
#   'negativeRisk': False},
#  {'proxyWallet': '0x6a72f61820b26b1fe4d956e17b6dc2a1ea3033ee',
#   'asset': '73051598223459218100992307779648724874702880467166988750991726075470877637679',
#   'conditionId': '0xfd7d9140f470a1b54965ae857ab3384ef088f35fe891b3b6b15662662aa7a51f',
#   'size': 414890.085299,
#   'avgPrice': 0.51,
#   'initialValue': 211593.94350248997,
#   'currentValue': 0,
#   'cashPnl': -211593.94350249,
#   'percentPnl': -100,
#   'totalBought': 414890.085299,
#   'realizedPnl': 0,
#   'percentRealizedPnl': -100,
#   'curPrice': 0,
#   'redeemable': True,
#   'mergeable': False,
#   'title': 'Spread: Cowboys (-3.5)',
#   'slug': 'nfl-dal-lv-2025-11-17-spread-away-3pt5',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nfl.png',
#   'eventId': '77437',
#   'eventSlug': 'nfl-dal-lv-2025-11-17',
#   'outcome': 'Raiders',
#   'outcomeIndex': 1,
#   'oppositeOutcome': 'Cowboys',
#   'oppositeAsset': '20526341283472765145712620878899102243965466931927215857611275014018771545170',
#   'endDate': '2025-11-18',
#   'negativeRisk': False},
#  {'proxyWallet': '0x6a72f61820b26b1fe4d956e17b6dc2a1ea3033ee',
#   'asset': '89618769767919113824957737002080514937979738837945124091798800409729291428281',
#   'conditionId': '0x44a461ebc2af9ad42262b7d571b935fadab23e65df4c03d8c183fa2adea54a1f',
#   'size': 400000,
#   'avgPrice': 0.48,
#   'initialValue': 192000,
#   'currentValue': 0,
#   'cashPnl': -192000,
#   'percentPnl': -100,
#   'totalBought': 400000,
#   'realizedPnl': 0,
#   'percentRealizedPnl': -100,
#   'curPrice': 0,
#   'redeemable': True,
#   'mergeable': False,
#   'title': 'Spread: Bucks (-6.5)',
#   'slug': 'nba-mil-sac-2026-01-04-spread-away-6pt5',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/super+cool+basketball+in+red+and+blue+wow.png',
#   'eventId': '131068',
#   'eventSlug': 'nba-mil-sac-2026-01-04',
#   'outcome': 'Kings',
#   'outcomeIndex': 1,
#   'oppositeOutcome': 'Bucks',
#   'oppositeAsset': '93570706773138185494069556039298765374542524894380326904756268646130733995026',
#   'endDate': '2026-01-05',
#   'negativeRisk': False},
#  {'proxyWallet': '0x6a72f61820b26b1fe4d956e17b6dc2a1ea3033ee',
#   'asset': '59009946994087861076613097879474976114675413207562272343863649872921303131844',
#   'conditionId': '0x0233726898878871b614787bef33e17ab60328bd257609546825e626c4770ca5',
#   'size': 400000,
#   'avgPrice': 0.49,
#   'initialValue': 196000,
#   'currentValue': 0,
#   'cashPnl': -196000,
#   'percentPnl': -100,
#   'totalBought': 400000,
#   'realizedPnl': 0,
#   'percentRealizedPnl': -100,
#   'curPrice': 0,
#   'redeemable': True,
#   'mergeable': False,
#   'title': 'Spread: Grizzlies (-3.5)',
#   'slug': 'nba-mem-sac-2025-11-30-spread-away-3pt5',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/super+cool+basketball+in+red+and+blue+wow.png',
#   'eventId': '89242',
#   'eventSlug': 'nba-mem-sac-2025-11-30',
#   'outcome': 'Kings',
#   'outcomeIndex': 1,
#   'oppositeOutcome': 'Grizzlies',
#   'oppositeAsset': '40100878303277860757570486571862758144881882677714389481929336288781290208895',
#   'endDate': '2025-12-01',
#   'negativeRisk': False},
#  {'proxyWallet': '0x6a72f61820b26b1fe4d956e17b6dc2a1ea3033ee',
#   'asset': '67613685408917637991826910249385903024104916322977984918515227735403430428130',
#   'conditionId': '0xc48fcf49b52f5687875d5636f718ff726a18a108c086cfc726eabf130eacc3e3',
#   'size': 400000,
#   'avgPrice': 0.38,
#   'initialValue': 152000,
#   'currentValue': 0,
#   'cashPnl': -152000,
#   'percentPnl': -100,
#   'totalBought': 400000,
#   'realizedPnl': 0,
#   'percentRealizedPnl': -100,
#   'curPrice': 0,
#   'redeemable': True,
#   'mergeable': False,
#   'title': 'Knicks vs. Spurs',
#   'slug': 'nba-nyk-sas-2025-12-31',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/super+cool+basketball+in+red+and+blue+wow.png',
#   'eventId': '123201',
#   'eventSlug': 'nba-nyk-sas-2025-12-31',
#   'outcome': 'Knicks',
#   'outcomeIndex': 0,
#   'oppositeOutcome': 'Spurs',
#   'oppositeAsset': '111216292895804341257406454588804122156610327291244192372975507677343783870150',
#   'endDate': '2026-01-01',
#   'negativeRisk': False},
#  {'proxyWallet': '0x6a72f61820b26b1fe4d956e17b6dc2a1ea3033ee',
#   'asset': '23432374606865188913534620175245780411982390065443735840624698153789999218111',
#   'conditionId': '0x050d56238205069e92229a853906e2f565310b59db8a95981d4b423c7ffe1ca9',
#   'size': 399999.994338,
#   'avgPrice': 0.47,
#   'initialValue': 187999.99733886,
#   'currentValue': 0,
#   'cashPnl': -187999.99733885998,
#   'percentPnl': -100,
#   'totalBought': 399999.994338,
#   'realizedPnl': 0,
#   'percentRealizedPnl': -100,
#   'curPrice': 0,
#   'redeemable': True,
#   'mergeable': False,
#   'title': 'Spread: Rockets (-7.5)',
#   'slug': 'nba-hou-lac-2025-12-23-spread-away-7pt5',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/super+cool+basketball+in+red+and+blue+wow.png',
#   'eventId': '107512',
#   'eventSlug': 'nba-hou-lac-2025-12-23',
#   'outcome': 'Rockets',
#   'outcomeIndex': 0,
#   'oppositeOutcome': 'Clippers',
#   'oppositeAsset': '110905626237424342578828160475400419780297158487185875268778164414756659897144',
#   'endDate': '2025-12-24',
#   'negativeRisk': False},
#  {'proxyWallet': '0x6a72f61820b26b1fe4d956e17b6dc2a1ea3033ee',
#   'asset': '52465471750776066764708550115570895586889121726895579349488964775006129922057',
#   'conditionId': '0x755ef82493ffb871b36605f1e54dfeb0cff443cc820acb07547fc9d69ee3de29',
#   'size': 399999.979992,
#   'avgPrice': 0.32,
#   'initialValue': 127999.99359744,
#   'currentValue': 0,
#   'cashPnl': -127999.99359744,
#   'percentPnl': -100,
#   'totalBought': 399999.979992,
#   'realizedPnl': 0,
#   'percentRealizedPnl': -100,
#   'curPrice': 0,
#   'redeemable': True,
#   'mergeable': False,
#   'title': 'Knicks vs. Raptors',
#   'slug': 'nba-nyk-tor-2025-12-09',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/super+cool+basketball+in+red+and+blue+wow.png',
#   'eventId': '96463',
#   'eventSlug': 'nba-nyk-tor-2025-12-09',
#   'outcome': 'Raptors',
#   'outcomeIndex': 1,
#   'oppositeOutcome': 'Knicks',
#   'oppositeAsset': '13074602576810380801040282699634023434828916276522050620955510477039962092517',
#   'endDate': '2025-12-10',
#   'negativeRisk': False},
#  {'proxyWallet': '0x6a72f61820b26b1fe4d956e17b6dc2a1ea3033ee',
#   'asset': '27887481627533078210436105816339582329208302668772658985491126599747137465542',
#   'conditionId': '0xa9202d1a3f497869d45ec1b122216de7ba542b2920d7becc64f0f9c2969a297f',
#   'size': 357296.938425,
#   'avgPrice': 0.140805,
#   'initialValue': 50309.195414932125,
#   'currentValue': 0,
#   'cashPnl': -50309.19541493213,
#   'percentPnl': -100,
#   'totalBought': 362514.574787,
#   'realizedPnl': 1991.644846,
#   'percentRealizedPnl': -99.99999609816996,
#   'curPrice': 0,
#   'redeemable': True,
#   'mergeable': False,
#   'title': 'Ravens vs. Dolphins',
#   'slug': 'nfl-bal-mia-2025-10-30',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nfl.png',
#   'eventId': '65481',
#   'eventSlug': 'nfl-bal-mia-2025-10-30',
#   'outcome': 'Dolphins',
#   'outcomeIndex': 1,
#   'oppositeOutcome': 'Ravens',
#   'oppositeAsset': '19107411353903294968863666132831741761932499489076109955229662722336998211898',
#   'endDate': '2025-11-07',
#   'negativeRisk': False},
#  {'proxyWallet': '0x6a72f61820b26b1fe4d956e17b6dc2a1ea3033ee',
#   'asset': '91300206831635196778103299717355585901610751268028689693952935455026055645833',
#   'conditionId': '0xeea11838031898568d1cf6be17f07bbaf33df76dfc0d1ea206d4bd817aaa2785',
#   'size': 327452.280967,
#   'avgPrice': 0.186623,
#   'initialValue': 61110.12703090444,
#   'currentValue': 0,
#   'cashPnl': -61110.12703090444,
#   'percentPnl': -100,
#   'totalBought': 327452.280967,
#   'realizedPnl': 0,
#   'percentRealizedPnl': -100,
#   'curPrice': 0,
#   'redeemable': True,
#   'mergeable': False,
#   'title': 'Commanders vs. Chiefs',
#   'slug': 'nfl-was-kc-2025-10-27',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nfl.png',
#   'eventId': '62068',
#   'eventSlug': 'nfl-was-kc-2025-10-27',
#   'outcome': 'Commanders',
#   'outcomeIndex': 0,
#   'oppositeOutcome': 'Chiefs',
#   'oppositeAsset': '58732316265160509330792138022029193686984698496575854235567332240128268819225',
#   'endDate': '2025-11-04',
#   'negativeRisk': False},
#  {'proxyWallet': '0x6a72f61820b26b1fe4d956e17b6dc2a1ea3033ee',
#   'asset': '13117756923306127898065043252667191816462130752849312110303187595120335163099',
#   'conditionId': '0xe84b0a1ca149ce35cd607ba294feeb43900a70473961289e11a9bce0bc83cffd',
#   'size': 303000,
#   'avgPrice': 0.490032,
#   'initialValue': 148479.696,
#   'currentValue': 153015,
#   'cashPnl': 4535.304,
#   'percentPnl': 3.0544944003656904,
#   'totalBought': 303000,
#   'realizedPnl': 0,
#   'percentRealizedPnl': 3.0544944003656904,
#   'curPrice': 0.505,
#   'redeemable': False,
#   'mergeable': False,
#   'title': 'Mavericks vs. Jazz: O/U 241.5',
#   'slug': 'nba-dal-uta-2026-01-08-total-241pt5',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/super+cool+basketball+in+red+and+blue+wow.png',
#   'eventId': '138802',
#   'eventSlug': 'nba-dal-uta-2026-01-08',
#   'outcome': 'Under',
#   'outcomeIndex': 1,
#   'oppositeOutcome': 'Over',
#   'oppositeAsset': '37648381702250245575420632003100022781038082995981826114957022180376625584913',
#   'endDate': '2026-01-09',
#   'negativeRisk': False},
#  {'proxyWallet': '0x6a72f61820b26b1fe4d956e17b6dc2a1ea3033ee',
#   'asset': '38841892593145254462801343558526805563235458593205670204256045483466836096827',
#   'conditionId': '0xa0b02a63b2d8ae8ea060bac9fba3b4e870aca11b8db98516c23055fa69058a81',
#   'size': 276782.681004,
#   'avgPrice': 0.465051,
#   'initialValue': 128718.0625835912,
#   'currentValue': 0,
#   'cashPnl': -128718.0625835912,
#   'percentPnl': -100,
#   'totalBought': 290406.634106,
#   'realizedPnl': 476.143536,
#   'percentRealizedPnl': -99.99999964744183,
#   'curPrice': 0,
#   'redeemable': True,
#   'mergeable': False,
#   'title': 'Senators vs. Blue Jackets',
#   'slug': 'nhl-ott-cbj-2025-12-12',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nhl.png',
#   'eventId': '81469',
#   'eventSlug': 'nhl-ott-cbj-2025-12-12',
#   'outcome': 'Blue Jackets',
#   'outcomeIndex': 1,
#   'oppositeOutcome': 'Senators',
#   'oppositeAsset': '100058761446464950006221142188556683241780183170292042370080052679952752749057',
#   'endDate': '2025-12-12',
#   'negativeRisk': False},
#  {'proxyWallet': '0x6a72f61820b26b1fe4d956e17b6dc2a1ea3033ee',
#   'asset': '24456846538887739512232291364838054048028015579629104827346546293315255654405',
#   'conditionId': '0xd6aa2b6c119726990e3fbb3280f8f48cbc92de17c71d93e9eb86019596b6ec2f',
#   'size': 267373.631375,
#   'avgPrice': 0.274626,
#   'initialValue': 73427.75088999076,
#   'currentValue': 0,
#   'cashPnl': -73427.75088999074,
#   'percentPnl': -100,
#   'totalBought': 302497.087088,
#   'realizedPnl': 7915.913707,
#   'percentRealizedPnl': -99.99999047120018,
#   'curPrice': 0,
#   'redeemable': True,
#   'mergeable': False,
#   'title': 'Packers vs. Giants',
#   'slug': 'nfl-gb-nyg-2025-11-16',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nfl.png',
#   'eventId': '76632',
#   'eventSlug': 'nfl-gb-nyg-2025-11-16',
#   'outcome': 'Giants',
#   'outcomeIndex': 1,
#   'oppositeOutcome': 'Packers',
#   'oppositeAsset': '37363436884881346959741752739715914342199430606149014949365926422093132942420',
#   'endDate': '2025-11-23',
#   'negativeRisk': False},
#  {'proxyWallet': '0x6a72f61820b26b1fe4d956e17b6dc2a1ea3033ee',
#   'asset': '18004562763660315242408153644620145125610709972276131108642467552261268539178',
#   'conditionId': '0x035ef1de0d295ce196015f7f3177479f6f2e0965b07770f4e61f1b6a57762d7c',
#   'size': 256098.03,
#   'avgPrice': 0.49,
#   'initialValue': 125488.0347,
#   'currentValue': 0,
#   'cashPnl': -125488.0347,
#   'percentPnl': -100,
#   'totalBought': 256098.03,
#   'realizedPnl': 0,
#   'percentRealizedPnl': -100,
#   'curPrice': 0,
#   'redeemable': True,
#   'mergeable': False,
#   'title': 'Spread: Trail Blazers (-8.5)',
#   'slug': 'nba-sac-por-2025-12-18-spread-home-8pt5',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/super+cool+basketball+in+red+and+blue+wow.png',
#   'eventId': '103310',
#   'eventSlug': 'nba-sac-por-2025-12-18',
#   'outcome': 'Trail Blazers',
#   'outcomeIndex': 0,
#   'oppositeOutcome': 'Kings',
#   'oppositeAsset': '78080061926132378231288450795400930321743427507644404413204280788988121271007',
#   'endDate': '2025-12-19',
#   'negativeRisk': False},
#  {'proxyWallet': '0x6a72f61820b26b1fe4d956e17b6dc2a1ea3033ee',
#   'asset': '81967987145301921718088974044666441502379158263655190422891099818551793805966',
#   'conditionId': '0x80c4606d9358e3cbbe6ae2cb8548b3d3cc951324d8d7f52aeafe6d1d87d8df23',
#   'size': 250000,
#   'avgPrice': 0.52,
#   'initialValue': 130000,
#   'currentValue': 0,
#   'cashPnl': -130000,
#   'percentPnl': -100,
#   'totalBought': 250000,
#   'realizedPnl': 0,
#   'percentRealizedPnl': -100,
#   'curPrice': 0,
#   'redeemable': True,
#   'mergeable': False,
#   'title': 'Rams vs. Seahawks: O/U 42.5',
#   'slug': 'nfl-la-sea-2025-12-18-total-42pt5',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nfl.png',
#   'eventId': '97878',
#   'eventSlug': 'nfl-la-sea-2025-12-18',
#   'outcome': 'Under',
#   'outcomeIndex': 1,
#   'oppositeOutcome': 'Over',
#   'oppositeAsset': '17914245076701791217941797855875453747375201200652132426193861075819167903080',
#   'endDate': '2025-12-19',
#   'negativeRisk': False},
#  {'proxyWallet': '0x6a72f61820b26b1fe4d956e17b6dc2a1ea3033ee',
#   'asset': '33931948865915818306785057432951939558486072002766867081489502199890379087385',
#   'conditionId': '0x8172e6b2ba87e8b61f780db502e62679fc8e1053f6acfc3aebbdb336efb91401',
#   'size': 248183.63,
#   'avgPrice': 0.54,
#   'initialValue': 134019.1602,
#   'currentValue': 0,
#   'cashPnl': -134019.1602,
#   'percentPnl': -100,
#   'totalBought': 248183.63,
#   'realizedPnl': 0,
#   'percentRealizedPnl': -99.99999999999999,
#   'curPrice': 0,
#   'redeemable': True,
#   'mergeable': False,
#   'title': 'Spread: Buccaneers (-2.5)',
#   'slug': 'nfl-car-tb-2026-01-04-spread-home-2pt5',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nfl.png',
#   'eventId': '115301',
#   'eventSlug': 'nfl-car-tb-2026-01-04',
#   'outcome': 'Buccaneers',
#   'outcomeIndex': 0,
#   'oppositeOutcome': 'Panthers',
#   'oppositeAsset': '114199361086829871899655015323003972065173340509248205718640330011929145318217',
#   'endDate': '2026-01-04',
#   'negativeRisk': False},
#  {'proxyWallet': '0x6a72f61820b26b1fe4d956e17b6dc2a1ea3033ee',
#   'asset': '78839755649604920924051409730052913195353224778311536180128498069501197581869',
#   'conditionId': '0xa0dc554ae17c2bd807cca427d172bd17e741c9b219355a5ab97c411931e4a48e',
#   'size': 237582.062434,
#   'avgPrice': 0.51,
#   'initialValue': 121166.85184134,
#   'currentValue': 0,
#   'cashPnl': -121166.85184134,
#   'percentPnl': -100,
#   'totalBought': 237582.062434,
#   'realizedPnl': 0,
#   'percentRealizedPnl': -100,
#   'curPrice': 0,
#   'redeemable': True,
#   'mergeable': False,
#   'title': 'Bucks vs. Nets',
#   'slug': 'nba-mil-bkn-2025-12-14',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/super+cool+basketball+in+red+and+blue+wow.png',
#   'eventId': '99927',
#   'eventSlug': 'nba-mil-bkn-2025-12-14',
#   'outcome': 'Bucks',
#   'outcomeIndex': 0,
#   'oppositeOutcome': 'Nets',
#   'oppositeAsset': '95194536383677230940604707066741273351932011703250978696393236065896314711105',
#   'endDate': '2025-12-14',
#   'negativeRisk': False},
#  {'proxyWallet': '0x6a72f61820b26b1fe4d956e17b6dc2a1ea3033ee',
#   'asset': '14989557310950586686400767785656852807985749758915743815781575926401299872055',
#   'conditionId': '0x6179c2ee8c636d84013134713eabdf48ae720d9acf521fa2ed6d7efef59fda62',
#   'size': 219999.99846,
#   'avgPrice': 0.475453,
#   'initialValue': 104599.65926780239,
#   'currentValue': 0,
#   'cashPnl': -104599.65926780239,
#   'percentPnl': -100,
#   'totalBought': 219999.99846,
#   'realizedPnl': 0,
#   'percentRealizedPnl': -100,
#   'curPrice': 0,
#   'redeemable': True,
#   'mergeable': False,
#   'title': 'Jets vs. Canadiens: O/U 6.5',
#   'slug': 'nhl-wpg-mon-2025-12-03-total-6pt5',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nhl.png',
#   'eventId': '74671',
#   'eventSlug': 'nhl-wpg-mon-2025-12-03',
#   'outcome': 'Over',
#   'outcomeIndex': 0,
#   'oppositeOutcome': 'Under',
#   'oppositeAsset': '91769478455542964737748139609210781912688881175456409064617504810061137815675',
#   'endDate': '2025-12-04',
#   'negativeRisk': False},
#  {'proxyWallet': '0x6a72f61820b26b1fe4d956e17b6dc2a1ea3033ee',
#   'asset': '34008882006586743025917171327631517196178656707550483813538223911544374700637',
#   'conditionId': '0x2b870064f3994875a3d680056bf9d3cdfd3f3e1785eb43e1bbe22d0021398f93',
#   'size': 219148.902717,
#   'avgPrice': 0.381574,
#   'initialValue': 83621.52340533656,
#   'currentValue': 0,
#   'cashPnl': -83621.52340533656,
#   'percentPnl': -100,
#   'totalBought': 290987.013531,
#   'realizedPnl': 8507.500111,
#   'percentRealizedPnl': -99.99999233786883,
#   'curPrice': 0,
#   'redeemable': True,
#   'mergeable': False,
#   'title': 'Colts vs. Chiefs',
#   'slug': 'nfl-ind-kc-2025-11-23',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nfl.png',
#   'eventId': '82597',
#   'eventSlug': 'nfl-ind-kc-2025-11-23',
#   'outcome': 'Colts',
#   'outcomeIndex': 0,
#   'oppositeOutcome': 'Chiefs',
#   'oppositeAsset': '112985492010640841950454510438501555987749530613705622744892618363690330237976',
#   'endDate': '2025-11-30',
#   'negativeRisk': False},
#  {'proxyWallet': '0x6a72f61820b26b1fe4d956e17b6dc2a1ea3033ee',
#   'asset': '81040111949664436829925018139800621400210016575620480393211069692865625741264',
#   'conditionId': '0x0c48f7df4f77deb98b175deaf1c229d2daeb9fbbb5c0954e424195fda3398624',
#   'size': 218340.660361,
#   'avgPrice': 0.4829,
#   'initialValue': 105436.7048883269,
#   'currentValue': 0,
#   'cashPnl': -105436.7048883269,
#   'percentPnl': -100,
#   'totalBought': 219548.383138,
#   'realizedPnl': 6.196825,
#   'percentRealizedPnl': -99.99999999415505,
#   'curPrice': 0,
#   'redeemable': True,
#   'mergeable': False,
#   'title': 'Blue Jackets vs. Ducks',
#   'slug': 'nhl-cbj-ana-2025-12-20',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nhl.png',
#   'eventId': '88544',
#   'eventSlug': 'nhl-cbj-ana-2025-12-20',
#   'outcome': 'Blue Jackets',
#   'outcomeIndex': 0,
#   'oppositeOutcome': 'Ducks',
#   'oppositeAsset': '115297505521890425185721445318540289240374502639131011698993345838530795203822',
#   'endDate': '2025-12-21',
#   'negativeRisk': False},
#  {'proxyWallet': '0x6a72f61820b26b1fe4d956e17b6dc2a1ea3033ee',
#   'asset': '60807914418467441687972335646119094696646319274502742902904773460393089061750',
#   'conditionId': '0x07e387a517f16e07e8159e8df6ff5785bed4b95ed2df86ec8f4e56e6c9e0546b',
#   'size': 214878.999966,
#   'avgPrice': 0.525434,
#   'initialValue': 112904.73246813525,
#   'currentValue': 0,
#   'cashPnl': -112904.73246813523,
#   'percentPnl': -100,
#   'totalBought': 214878.999966,
#   'realizedPnl': 0,
#   'percentRealizedPnl': -100.00000000000003,
#   'curPrice': 0,
#   'redeemable': True,
#   'mergeable': False,
#   'title': 'Spread: Falcons (-3.5)',
#   'slug': 'nfl-no-atl-2026-01-04-spread-home-3pt5',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nfl.png',
#   'eventId': '115288',
#   'eventSlug': 'nfl-no-atl-2026-01-04',
#   'outcome': 'Falcons',
#   'outcomeIndex': 0,
#   'oppositeOutcome': 'Saints',
#   'oppositeAsset': '106820326677034857691173358617337118787258857357873588240521307537093660496173',
#   'endDate': '2026-01-04',
#   'negativeRisk': False},
#  {'proxyWallet': '0x6a72f61820b26b1fe4d956e17b6dc2a1ea3033ee',
#   'asset': '31613637341220849604612306056990169835469645605460360898226804918237455634262',
#   'conditionId': '0xc130c2f95fe1169d9db1015935284199c08fc2633e05462742db44b6d15992aa',
#   'size': 207822.825203,
#   'avgPrice': 0.459672,
#   'initialValue': 95530.33370671341,
#   'currentValue': 0,
#   'cashPnl': -95530.33370671343,
#   'percentPnl': -100,
#   'totalBought': 308257.436797,
#   'realizedPnl': 3403.044737,
#   'percentRealizedPnl': -99.9999975983703,
#   'curPrice': 0,
#   'redeemable': True,
#   'mergeable': False,
#   'title': 'Predators vs. Blackhawks',
#   'slug': 'nhl-nsh-chi-2025-11-28',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nhl.png',
#   'eventId': '70535',
#   'eventSlug': 'nhl-nsh-chi-2025-11-28',
#   'outcome': 'Blackhawks',
#   'outcomeIndex': 1,
#   'oppositeOutcome': 'Predators',
#   'oppositeAsset': '66155983928976561517841940512758896390614953923405167122324971552674692014907',
#   'endDate': '2025-11-28',
#   'negativeRisk': False},
#  {'proxyWallet': '0x6a72f61820b26b1fe4d956e17b6dc2a1ea3033ee',
#   'asset': '33267677499872019653010941912472260068992120719086259448494819799477078420262',
#   'conditionId': '0x955670282e570980c9f380e5968fd07c7e425a461095451fdcc3adcc8afa236a',
#   'size': 200961.09438,
#   'avgPrice': 0.449942,
#   'initialValue': 90420.83672752595,
#   'currentValue': 0,
#   'cashPnl': -90420.83672752595,
#   'percentPnl': -100,
#   'totalBought': 200961.09438,
#   'realizedPnl': 0,
#   'percentRealizedPnl': -100,
#   'curPrice': 0,
#   'redeemable': True,
#   'mergeable': False,
#   'title': 'Hawks vs. Jazz',
#   'slug': 'nba-atl-uta-2025-11-13',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/super+cool+basketball+in+red+and+blue+wow.png',
#   'eventId': '75366',
#   'eventSlug': 'nba-atl-uta-2025-11-13',
#   'outcome': 'Jazz',
#   'outcomeIndex': 1,
#   'oppositeOutcome': 'Hawks',
#   'oppositeAsset': '112138823621306660544961530428237388266003156586798106103403358748390185083335',
#   'endDate': '2025-11-14',
#   'negativeRisk': False},
#  {'proxyWallet': '0x6a72f61820b26b1fe4d956e17b6dc2a1ea3033ee',
#   'asset': '95835504229908760323417282060864861901655385063470023450912119465783489033099',
#   'conditionId': '0xf2a809a858dbf21addc08b21daa15561e73e016bc0fd70bb23378f503a6ef3d6',
#   'size': 200000,
#   'avgPrice': 0.33,
#   'initialValue': 66000,
#   'currentValue': 0,
#   'cashPnl': -66000,
#   'percentPnl': -100,
#   'totalBought': 200000,
#   'realizedPnl': 0,
#   'percentRealizedPnl': -100,
#   'curPrice': 0,
#   'redeemable': True,
#   'mergeable': False,
#   'title': 'Alabama Crimson Tide vs. Gonzaga Bulldogs',
#   'slug': 'cbb-ala-gnzg-2025-11-24',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/ncaa-c14995df96.png',
#   'eventId': '84457',
#   'eventSlug': 'cbb-ala-gnzg-2025-11-24',
#   'outcome': 'Alabama Crimson Tide',
#   'outcomeIndex': 0,
#   'oppositeOutcome': 'Gonzaga Bulldogs',
#   'oppositeAsset': '112244151576180248259882275626593138234196496491932807146165947799472365884679',
#   'endDate': '2025-11-25',
#   'negativeRisk': False},
#  {'proxyWallet': '0x6a72f61820b26b1fe4d956e17b6dc2a1ea3033ee',
#   'asset': '51062797508522466158407503723098008038181935224722221587977492630154046949130',
#   'conditionId': '0xbb15d13e998e2370e8dde27bfca317941dba23aac539cfef1b04c998c2f8bae7',
#   'size': 200000,
#   'avgPrice': 0.58,
# ...
#   'avgPrice': 0.502986,
#   'initialValue': 48580.41313753643,
#   'currentValue': 0,
#   'cashPnl': -48580.41313753644,
#   'percentPnl': -100,
#   'totalBought': 96584.026469,
#   'realizedPnl': 0,
#   'percentRealizedPnl': -99.99999999999999,
#   'curPrice': 0,
#   'redeemable': True,
#   'mergeable': False,
#   'title': 'Penguins vs. Senators: O/U 6.5',
#   'slug': 'nhl-pit-ott-2025-12-18-total-6pt5',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nhl.png',
#   'eventId': '86969',
#   'eventSlug': 'nhl-pit-ott-2025-12-18',
#   'outcome': 'Over',
#   'outcomeIndex': 0,
#   'oppositeOutcome': 'Under',
#   'oppositeAsset': '23923015446186683513861952227816524564978332739762075419960801282382202516240',
#   'endDate': '2025-12-19',
#   'negativeRisk': False},
#  {'proxyWallet': '0x6a72f61820b26b1fe4d956e17b6dc2a1ea3033ee',
#   'asset': '61285982630425567993820136513648011697899595186528516828411254526155460181391',
#   'conditionId': '0x35299ef93cb05afc0591faa883c29ece317b78e9d42da9ec88b65b1af6da51cb',
#   'size': 95860.54184,
#   'avgPrice': 0.201081,
#   'initialValue': 19275.73361372904,
#   'currentValue': 0,
#   'cashPnl': -19275.73361372904,
#   'percentPnl': -100,
#   'totalBought': 116373.410373,
#   'realizedPnl': 5310.050562,
#   'percentRealizedPnl': -99.99997730794337,
#   'curPrice': 0,
#   'redeemable': True,
#   'mergeable': False,
#   'title': 'Cardinals vs. Saints',
#   'slug': 'nfl-ari-no-2025-09-07',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nfl.png',
#   'eventId': '40822',
#   'eventSlug': 'nfl-ari-no-2025-09-07',
#   'outcome': 'Saints',
#   'outcomeIndex': 1,
#   'oppositeOutcome': 'Cardinals',
#   'oppositeAsset': '43344777803350518012170161123794413176289743480500560100983860627490586822882',
#   'endDate': '2025-09-14',
#   'negativeRisk': False},
#  {'proxyWallet': '0x6a72f61820b26b1fe4d956e17b6dc2a1ea3033ee',
#   'asset': '63352664087391117918915676524256229625928896522483698507923638475418781426669',
#   'conditionId': '0x9da3ff37ed004859707cbf2e120d3dce327b6dfc8dbf2193447417a00f418b6b',
#   'size': 94424.990537,
#   'avgPrice': 0.26,
#   'initialValue': 24550.49753962,
#   'currentValue': 0,
#   'cashPnl': -24550.49753962,
#   'percentPnl': -100,
#   'totalBought': 94424.990537,
#   'realizedPnl': 0,
#   'percentRealizedPnl': -100,
#   'curPrice': 0,
#   'redeemable': True,
#   'mergeable': False,
#   'title': 'North Carolina State Wolfpack vs. Boise State Broncos',
#   'slug': 'cbb-ncst-boise-2025-11-25',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/ncaa-c14995df96.png',
#   'eventId': '90119',
#   'eventSlug': 'cbb-ncst-boise-2025-11-25',
#   'outcome': 'Boise State Broncos',
#   'outcomeIndex': 1,
#   'oppositeOutcome': 'North Carolina State Wolfpack',
#   'oppositeAsset': '102001903738769467900475990930610436806455632018042706151162749716586055400218',
#   'endDate': '2025-11-25',
#   'negativeRisk': False},
#  {'proxyWallet': '0x6a72f61820b26b1fe4d956e17b6dc2a1ea3033ee',
#   'asset': '85660995210960339249031130571716132249396560397420298921539776481717501210230',
#   'conditionId': '0xf32f35850e555afdb655a8af329946a2dc04de3290999b0c14bbf7cb4123a160',
#   'size': 92474.101277,
#   'avgPrice': 0.130182,
#   'initialValue': 12038.463452442415,
#   'currentValue': 0,
#   'cashPnl': -12038.463452442413,
#   'percentPnl': -100,
#   'totalBought': 100056.796913,
#   'realizedPnl': 2804.217334,
#   'percentRealizedPnl': -99.99997847148202,
#   'curPrice': 0,
#   'redeemable': True,
#   'mergeable': False,
#   'title': 'LAR vs. Cardinals',
#   'slug': 'nfl-la-ari-2025-12-07',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nfl.png',
#   'eventId': '89375',
#   'eventSlug': 'nfl-la-ari-2025-12-07',
#   'outcome': 'Cardinals',
#   'outcomeIndex': 1,
#   'oppositeOutcome': 'LAR',
#   'oppositeAsset': '10403706480644138747994402283691709956401104167443241781989818636970154291162',
#   'endDate': '2025-12-07',
#   'negativeRisk': False},
#  {'proxyWallet': '0x6a72f61820b26b1fe4d956e17b6dc2a1ea3033ee',
#   'asset': '87918864565491471386671337550198987821013545780599955289795581515743085459873',
#   'conditionId': '0x959899cd8459386dd0b0e46d13ce7d6b693f864641643c8629ef18762ef88a32',
#   'size': 87252.7,
#   'avgPrice': 0.067604,
#   'initialValue': 5898.6315308,
#   'currentValue': 0,
#   'cashPnl': -5898.6315308,
#   'percentPnl': -100,
#   'totalBought': 87252.7,
#   'realizedPnl': 0,
#   'percentRealizedPnl': -100,
#   'curPrice': 0,
#   'redeemable': True,
#   'mergeable': False,
#   'title': 'Will the Baltimore Ravens win Super Bowl 2026?',
#   'slug': 'will-the-baltimore-ravens-win-super-bowl-2026',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/NFL+Team+Logos/BAL.png',
#   'eventId': '23656',
#   'eventSlug': 'super-bowl-champion-2026-731',
#   'outcome': 'Yes',
#   'outcomeIndex': 0,
#   'oppositeOutcome': 'No',
#   'oppositeAsset': '13650729373396863503149204494735335464119911986355339951778806205194377721658',
#   'endDate': '2026-02-08',
#   'negativeRisk': True},
#  {'proxyWallet': '0x6a72f61820b26b1fe4d956e17b6dc2a1ea3033ee',
#   'asset': '27395576905478902183689175603734818670009219416077871338648645113316328767003',
#   'conditionId': '0x00d918c24d336699a7b7a1f8dbef6abe039b2ee62a6883b0df05072a72f41929',
#   'size': 84451.5164,
#   'avgPrice': 0.5,
#   'initialValue': 42225.7582,
#   'currentValue': 0,
#   'cashPnl': -42225.7582,
#   'percentPnl': -100,
#   'totalBought': 84451.5164,
#   'realizedPnl': 0,
#   'percentRealizedPnl': -100,
#   'curPrice': 0,
#   'redeemable': True,
#   'mergeable': False,
#   'title': 'Spread: North Carolina State (-3.5)',
#   'slug': 'cfb-mphs-ncst-2025-12-19-spread-home-3pt5',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/espn+college+football+logo.png',
#   'eventId': '105900',
#   'eventSlug': 'cfb-mphs-ncst-2025-12-19',
#   'outcome': 'Memphis',
#   'outcomeIndex': 1,
#   'oppositeOutcome': 'North Carolina State',
#   'oppositeAsset': '70362674987843460607922983942793384611036072221061734103994459268120250472638',
#   'endDate': '2025-12-19',
#   'negativeRisk': False},
#  {'proxyWallet': '0x6a72f61820b26b1fe4d956e17b6dc2a1ea3033ee',
#   'asset': '7243589198875364970387376718438124675468037047024558533126861151914733407362',
#   'conditionId': '0xa81a016f6a423279f2544bb27dd7b2d680ed3675cf27f890cd096c15a9177bf1',
#   'size': 80638.559539,
#   'avgPrice': 0.44951,
#   'initialValue': 36247.838898375885,
#   'currentValue': 0,
#   'cashPnl': -36247.83889837589,
#   'percentPnl': -100,
#   'totalBought': 80638.559539,
#   'realizedPnl': 0,
#   'percentRealizedPnl': -99.99999999999997,
#   'curPrice': 0,
#   'redeemable': True,
#   'mergeable': False,
#   'title': 'Kings vs. Penguins',
#   'slug': 'nhl-lak-pit-2025-11-09',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nhl.png',
#   'eventId': '58985',
#   'eventSlug': 'nhl-lak-pit-2025-11-09',
#   'outcome': 'Penguins',
#   'outcomeIndex': 1,
#   'oppositeOutcome': 'Kings',
#   'oppositeAsset': '19113949069904931199778917400068631672979665784275572280498013808885035729468',
#   'endDate': '2025-11-09',
#   'negativeRisk': False},
#  {'proxyWallet': '0x6a72f61820b26b1fe4d956e17b6dc2a1ea3033ee',
#   'asset': '82266042348709574099107387758039300383236662534232048447900866345027503608279',
#   'conditionId': '0xf9a91e0b4a01d15141719a2e8afbcb016ee55fd6261545a556ff368f6358cbc6',
#   'size': 79400.935011,
#   'avgPrice': 0.554211,
#   'initialValue': 44004.87159338132,
#   'currentValue': 0,
#   'cashPnl': -44004.87159338132,
#   'percentPnl': -100,
#   'totalBought': 79400.935011,
#   'realizedPnl': 0,
#   'percentRealizedPnl': -99.99999999999997,
#   'curPrice': 0,
#   'redeemable': True,
#   'mergeable': False,
#   'title': 'Capitals vs. Sharks: O/U 6.5',
#   'slug': 'nhl-wsh-sj-2025-12-03-total-6pt5',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nhl.png',
#   'eventId': '74673',
#   'eventSlug': 'nhl-wsh-sj-2025-12-03',
#   'outcome': 'Under',
#   'outcomeIndex': 1,
#   'oppositeOutcome': 'Over',
#   'oppositeAsset': '95715106741376054116352004173695776398988979965280359995038979864896385063031',
#   'endDate': '2025-12-04',
#   'negativeRisk': False},
#  {'proxyWallet': '0x6a72f61820b26b1fe4d956e17b6dc2a1ea3033ee',
#   'asset': '9181967798454622536309961824233787731185869865526395853534602127363182830750',
#   'conditionId': '0xdf51b43c9120a03bf65e96be8faf215523dd96c112e422f83f70053f508c88c1',
#   'size': 78621.475379,
#   'avgPrice': 0.487273,
#   'initialValue': 38310.12217235146,
#   'currentValue': 0,
#   'cashPnl': -38310.12217235147,
#   'percentPnl': -100,
#   'totalBought': 78621.475379,
#   'realizedPnl': 0,
#   'percentRealizedPnl': -99.99999999999997,
#   'curPrice': 0,
#   'redeemable': True,
#   'mergeable': False,
#   'title': 'Blues vs. Sabres: O/U 6.5',
#   'slug': 'nhl-stl-buf-2025-11-06-total-6pt5',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nhl.png',
#   'eventId': '57446',
#   'eventSlug': 'nhl-stl-buf-2025-11-06',
#   'outcome': 'Over',
#   'outcomeIndex': 0,
#   'oppositeOutcome': 'Under',
#   'oppositeAsset': '66284923703656582447883444202082795292924137379976942483987525378531933188527',
#   'endDate': '2025-11-06',
#   'negativeRisk': False},
#  {'proxyWallet': '0x6a72f61820b26b1fe4d956e17b6dc2a1ea3033ee',
#   'asset': '26347687246839115950732535546299384861486320262400764305851501032275642845717',
#   'conditionId': '0xa1b2eccd54a266227099d0e8effa9659eeb6b34faf6594aca9ec9a1ed9e2150f',
#   'size': 77203.809352,
#   'avgPrice': 0.530003,
#   'initialValue': 40918.250567988056,
#   'currentValue': 0,
#   'cashPnl': -40918.250567988056,
#   'percentPnl': -100,
#   'totalBought': 77203.809352,
#   'realizedPnl': 0,
#   'percentRealizedPnl': -100,
#   'curPrice': 0,
#   'redeemable': True,
#   'mergeable': False,
#   'title': 'Western Kentucky vs. Southern Miss',
#   'slug': 'cfb-wkent-soumis-2025-12-23',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/espn+college+football+logo.png',
#   'eventId': '118096',
#   'eventSlug': 'cfb-wkent-soumis-2025-12-23',
#   'outcome': 'Southern Miss',
#   'outcomeIndex': 1,
#   'oppositeOutcome': 'Western Kentucky',
#   'oppositeAsset': '84149598749077424151692706324372147089880181286930895376957686999854877017909',
#   'endDate': '2025-12-23',
#   'negativeRisk': False},
#  {'proxyWallet': '0x6a72f61820b26b1fe4d956e17b6dc2a1ea3033ee',
#   'asset': '105805346739500992595592849942884155968780190054857892632628506313057317498606',
#   'conditionId': '0xc8f4ceaa457bacb2c35df6412f65c50596f17a1d43734d86895a4ce510b4585e',
#   'size': 75140.641664,
#   'avgPrice': 0.28,
#   'initialValue': 21039.37966592,
#   'currentValue': 0,
#   'cashPnl': -21039.37966592,
#   'percentPnl': -100,
#   'totalBought': 75140.641664,
#   'realizedPnl': 0,
#   'percentRealizedPnl': -99.99999999999997,
#   'curPrice': 0,
#   'redeemable': True,
#   'mergeable': False,
#   'title': 'Cavaliers vs. Pacers',
#   'slug': 'nba-cle-ind-2025-12-01',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/super+cool+basketball+in+red+and+blue+wow.png',
#   'eventId': '90112',
#   'eventSlug': 'nba-cle-ind-2025-12-01',
#   'outcome': 'Pacers',
#   'outcomeIndex': 1,
#   'oppositeOutcome': 'Cavaliers',
#   'oppositeAsset': '55399073910241110321143566417499514761728667602612836054219373213410921198138',
#   'endDate': '2025-12-02',
#   'negativeRisk': False},
#  {'proxyWallet': '0x6a72f61820b26b1fe4d956e17b6dc2a1ea3033ee',
#   'asset': '83558613626249522736089886744027177740252338774291901699723752588683649105250',
#   'conditionId': '0x2ac3d7d9706dc9082116909e8386caafb6194efe031b38c1f8fa2dfc1a2c5bbd',
#   'size': 74054.014657,
#   'avgPrice': 0.494575,
#   'initialValue': 36625.26429898578,
#   'currentValue': 0,
#   'cashPnl': -36625.26429898577,
#   'percentPnl': -100,
#   'totalBought': 74054.014657,
#   'realizedPnl': 0,
#   'percentRealizedPnl': -100.00000000000003,
#   'curPrice': 0,
#   'redeemable': True,
#   'mergeable': False,
#   'title': 'Kraken vs. Flames: O/U 5.5',
#   'slug': 'nhl-sea-cal-2025-12-18-total-5pt5',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nhl.png',
#   'eventId': '86974',
#   'eventSlug': 'nhl-sea-cal-2025-12-18',
#   'outcome': 'Under',
#   'outcomeIndex': 1,
#   'oppositeOutcome': 'Over',
#   'oppositeAsset': '5507766690778136106923466173916401710765231174109981415393652084886151836996',
#   'endDate': '2025-12-19',
#   'negativeRisk': False},
#  {'proxyWallet': '0x6a72f61820b26b1fe4d956e17b6dc2a1ea3033ee',
#   'asset': '45082141987689758674728324061905822559220331125021700585731988984548013732195',
#   'conditionId': '0xdbc1d30bf0a5c14034423e2244805d815abec953989ed1be10f512c68c1514be',
#   'size': 71859.626068,
#   'avgPrice': 0.787235,
#   'initialValue': 56570.41272764198,
#   'currentValue': 0,
#   'cashPnl': -56570.41272764198,
#   'percentPnl': -100,
#   'totalBought': 95679.019711,
#   'realizedPnl': -6841.763533,
#   'percentRealizedPnl': -100.00000908336881,
#   'curPrice': 0,
#   'redeemable': True,
#   'mergeable': False,
#   'title': 'Panthers vs. Falcons',
#   'slug': 'nfl-car-atl-2025-11-16',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nfl.png',
#   'eventId': '76621',
#   'eventSlug': 'nfl-car-atl-2025-11-16',
#   'outcome': 'Falcons',
#   'outcomeIndex': 1,
#   'oppositeOutcome': 'Panthers',
#   'oppositeAsset': '22528409334282609908458133828376988274628638848080566597476253206210736687945',
#   'endDate': '2025-11-23',
#   'negativeRisk': False},
#  {'proxyWallet': '0x6a72f61820b26b1fe4d956e17b6dc2a1ea3033ee',
#   'asset': '45756397739268050832890000235622514908125292971434560828695977281665859741364',
#   'conditionId': '0xbba6d1361ec0079da7dfa0085425ebd76861431ebaf7f1f4a0ab7d14f7df6e7a',
#   'size': 68018.344325,
#   'avgPrice': 0.525878,
#   'initialValue': 35769.35087694235,
#   'currentValue': 0,
#   'cashPnl': -35769.35087694234,
#   'percentPnl': -100,
#   'totalBought': 68018.344325,
#   'realizedPnl': 0,
#   'percentRealizedPnl': -100.00000000000003,
#   'curPrice': 0,
#   'redeemable': True,
#   'mergeable': False,
#   'title': 'Bruins vs. Ducks: O/U 6.5',
#   'slug': 'nhl-bos-ana-2025-11-19-total-6pt5',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nhl.png',
#   'eventId': '64065',
#   'eventSlug': 'nhl-bos-ana-2025-11-19',
#   'outcome': 'Under',
#   'outcomeIndex': 1,
#   'oppositeOutcome': 'Over',
#   'oppositeAsset': '58567577096436499346166270011472187912679535858776437354358296448401759897327',
#   'endDate': '2025-11-20',
#   'negativeRisk': False},
#  {'proxyWallet': '0x6a72f61820b26b1fe4d956e17b6dc2a1ea3033ee',
#   'asset': '79575812723473998267224322313983483442222138266457349006744608855045907390411',
#   'conditionId': '0xe1c1cfe25fa7d982a943264579081767708594952ea53ba3db8888d6fa79d853',
#   'size': 64051.991817,
#   'avgPrice': 0.45,
#   'initialValue': 28823.39631765,
#   'currentValue': 0,
#   'cashPnl': -28823.39631765,
#   'percentPnl': -100,
#   'totalBought': 64051.991817,
#   'realizedPnl': 0,
#   'percentRealizedPnl': -100,
#   'curPrice': 0,
#   'redeemable': True,
#   'mergeable': False,
#   'title': 'Pelicans vs. Bulls',
#   'slug': 'nba-nop-chi-2025-12-31',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/super+cool+basketball+in+red+and+blue+wow.png',
#   'eventId': '123197',
#   'eventSlug': 'nba-nop-chi-2025-12-31',
#   'outcome': 'Pelicans',
#   'outcomeIndex': 0,
#   'oppositeOutcome': 'Bulls',
#   'oppositeAsset': '102471752065475133701625773131644788936707947643451376607850377469818702724928',
#   'endDate': '2026-01-01',
#   'negativeRisk': False},
#  {'proxyWallet': '0x6a72f61820b26b1fe4d956e17b6dc2a1ea3033ee',
#   'asset': '67670942101692655280005862292586135586825938858651894275830331019608071025986',
#   'conditionId': '0xce2671dbf70a19b648b0e32aa55be99c70503bc9455a42a68829cc5186492c38',
#   'size': 61564.781302,
#   'avgPrice': 0.412251,
#   'initialValue': 25380.1426565308,
#   'currentValue': 0,
#   'cashPnl': -25380.1426565308,
#   'percentPnl': -100,
#   'totalBought': 61564.781302,
#   'realizedPnl': 0,
#   'percentRealizedPnl': -100,
#   'curPrice': 0,
#   'redeemable': True,
#   'mergeable': False,
#   'title': 'Chargers vs. Dolphins',
#   'slug': 'nfl-lac-mia-2025-10-12',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nfl.png',
#   'eventId': '54354',
#   'eventSlug': 'nfl-lac-mia-2025-10-12',
#   'outcome': 'Dolphins',
#   'outcomeIndex': 1,
#   'oppositeOutcome': 'Chargers',
#   'oppositeAsset': '84867841418196475051962678681100910112043935496708723987576604857633043303574',
#   'endDate': '2025-10-19',
#   'negativeRisk': False}]
